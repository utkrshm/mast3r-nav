# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import cv2
from PIL import Image
from natsort import natsorted

# %%
from viz_utils import plot_costmap_with_info, plot_query_img_with_costmap

# %% [markdown]
# ## Setting up the directories

# %%
# SCENE_DIR = Path("/home/onyx/work_dirs/vanshg/navigation/sg_habitat/data/hm3d_iin_val/DYehNKdT76V_0000000_toilet_115_")
SCENE_DIR = Path("../data/gs2_modified/img_L_1preF")

SCENE_IMG_DIR = SCENE_DIR / "images"
MAP_BASE_DIR = Path(os.path.abspath("../outputs/gs2_mapping_v1"))

SCENE_NAME = "img_L_1preF"
SCENE_MAP_DIR = MAP_BASE_DIR / SCENE_NAME

# %% [markdown]
# ## Loading and Plotting the training costmaps

# %%
costmaps_file = SCENE_MAP_DIR / "costmaps_320x240_EC_NONE_NC_NONE_NCF_10.npz"

costmaps_data = np.load(costmaps_file)
print("Costmaps data keys:", costmaps_data.files)
img_costmaps = costmaps_data["costmaps"]

img_paths = natsorted(SCENE_IMG_DIR.iterdir())
# goal_idx = costmaps_data["metadata"]["goal_idx"]
# goal_img = np.array(Image.open(img_paths[goal_idx]))

# plot_query_img_with_costmap(goal_img, img_costmaps[goal_idx])
for i, img_path in enumerate(img_paths):
    query_img = np.array(Image.open(img_path))
    if i % 3 == 0:
        plot_query_img_with_costmap(query_img, img_costmaps[i], step_id=i)
# Out:
# Costmaps data keys: ['costmaps', 'metadata']
# array('{"goal_img_idx": 50, "goal_pixel": [160, 120], "goal_node_id": 3878560, "cfg": {"image": {"width": 320, "height": 240}, "model": {"name": "mast3r", "path": "./checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth", "device": "cuda", "subsample_or_initxy1": 8}, "graph": {"inter_image_match_window_size": 3, "edge_culling_mode": "NONE", "node_culling_mode": "NONE", "node_culling_factor": 10}, "processing": {"subsample_start_idx": 0, "subsample_end_idx": null, "subsample_step": 1, "force_recompute_graph": true, "force_recompute_masks": false, "copy_images": false}, "compression": {"enabled": true, "chunk_size": 1073741824}, "scenes": {"dataset": "gostanford", "base_dir": "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/", "multi_scene": false, "base_out_dir": "./outputs/gs2_mapping_v1", "scene_name": "img_L_1preF", "scene_list_file": "./episodes_removing_blacklist.txt", "start_idx": 0, "end_idx": -1, "step": 1}, "goal": {"mode": "config", "image_idx": 50, "pixel_x": 160, "pixel_y": 120, "base_graph_path": null, "task_type": "original", "compute_costmaps": true}, "logging": {"verbose": true, "save_debug_info": false}}, "goal_coord_3d": [-0.010150052607059479, 0.009738506749272346, 6.734649658203125], "image_paths": ["/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_20_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_21_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_22_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_23_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_24_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_25_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_26_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_27_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_28_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_29_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_30_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_31_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_32_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_33_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_34_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_35_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_36_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_37_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_38_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_39_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_40_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_41_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_42_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_43_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_44_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_45_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_46_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_47_LF.jpg", "/home2/utkarsh.malaiya/mast3r-nav/data/gs2_modified/img_L_1preF/images/img_1pre_1_48_L ...
#       dtype='<U17896')

# %%
costmap_metadata = costmaps_data["metadata"]
print(costmap_metadata)
# Out:
# {"goal_img_idx": 82, "goal_pixel": [154, 60], "goal_node_id": 6316954, "cfg": {"image": {"width": 320, "height": 240, "hfov": 120}, "model": {"name": "mast3r", "path": "/home/onyx/work_dirs/vanshg/navigation/sg_habitat/libs/matcher/image_matching_models/matching/model_weights/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth", "device": "cuda", "subsample_or_initxy1": 8}, "graph": {"inter_image_match_window_size": 3, "edge_culling_mode": "EMST_SINGLE", "node_culling_mode": "NONE", "node_culling_factor": 10}, "processing": {"subsample_start_idx": 0, "subsample_end_idx": null, "subsample_step": 1, "force_recompute_graph": true, "force_recompute_masks": false, "copy_images": false}, "compression": {"enabled": true, "chunk_size": 1073741824}, "scenes": {"base_dir": "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240", "multi_scene": true, "base_out_dir": "/scratch2/public_scratch/vanshg/mast3r-nav/hm3d_val_mapping", "scene_name": "q3zU7Yy5E5s_0000000_bed_23_", "scene_list_file": "/home/onyx/work_dirs/vanshg/navigation/mast3r-nav/episodes_removing_blacklist.txt", "start_idx": 0, "end_idx": -1, "step": 1}, "goal": {"mode": "episode", "image_idx": 50, "pixel_x": 160, "pixel_y": 120, "base_graph_path": null, "task_type": "original", "compute_costmaps": true}, "logging": {"verbose": true, "save_debug_info": false}}, "goal_coord_3d": [-0.04161262512207031, -0.4379938840866089, 1.5974620580673218], "image_paths": ["/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00000.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00001.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00002.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00003.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00004.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00005.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00006.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00007.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00008.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00009.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00010.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00011.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00012.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00013.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00014.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor_31_/images/00015.png", "/scratch2/public_scratch/toponav/indoor-topo-loc/datasets/hm3d_navigation/hm3d_iin_val_320x240/Nfvxx8J5NCo_0000000_tv_monitor ...

# %%
COSTMAP_VIZ_DIR = MAP_DIR / "costmap_viz"
COSTMAP_VIZ_DIR.mkdir(exist_ok=True, parents=True)

# %%
num_images = img_costmaps.shape[0]

# Visualize and save costmaps with info
for i in range(num_images):
    costmap = img_costmaps[i]
    img_filename = f"costmap_{i:04d}.png"
    rgb_img_filename = SCENE_IMG_DIR / f"{i:05d}.png"
    rgb_img = cv2.imread(str(rgb_img_filename))
    save_path = COSTMAP_VIZ_DIR / img_filename
    plot_costmap_with_info(costmap, step_id=i, save_path=save_path)
